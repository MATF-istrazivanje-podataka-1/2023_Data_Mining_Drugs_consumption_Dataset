# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#uzeto iz fajla za analizu podataka
kolone = ["ID", "Age", "Gender", "Education", "Country", "Ethnicity", 
            "Nscore", "Escore", "Oscore", "Ascore", "Cscore", "Impulsiveness", "SS", 
            "Alchocol", "Amphet", "Amyl", "Benzos", "Caff", "Canabis", "Choc", "Coke", "Crack", "Ecstasy", 
            "Heroin", "Ketamin", "LegalH", "LSD", "Meth", "Mushrooms", "Nicotine", "Semer", "VSA"]

podaci = pd.read_csv('drug_consumption.data', names = kolone)

podaci = podaci.drop('ID', axis = 1)

# %%
klase = []
atributi = []
for x in podaci.columns:
    if x == 'Alchocol':
        break
    atributi.append(x)
    
for x in podaci.columns:
    if x not in atributi:
        klase.append(x)

# %%
podaci_skalirano = podaci.copy()

opisni_niz1 = podaci['Alchocol'].unique()
opisni_niz1.sort()
n = len(podaci_skalirano['Heroin'])
    
for x in klase:
    for i in range(n):
        podaci_skalirano[x][i] = int(podaci_skalirano[x][i].strip('CL'))
    print(podaci_skalirano[x].unique())
        

podaci_skalirano
# Out:
# /tmp/ipykernel_5164/4143100454.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   podaci_skalirano[x][i] = int(podaci_skalirano[x][i].strip('CL'))
# [5 6 4 2 1 0 3]
# [2 0 1 3 5 4 6]
# [0 2 1 3 5 4 6]
# [2 0 3 1 4 5 6]
# [6 5 4 3 0 1 2]
# [0 4 3 2 1 6 5]
# [5 6 4 0 3 2 1]
# [0 3 2 1 6 5 4]
# [0 1 2 3 5 4 6]
# [0 4 1 3 2 6 5]
# [0 1 2 3 5 6 4]
# [0 2 3 1 5 4 6]
# [0 1 2 3 5 4 6]
# [0 2 1 3 4 5 6]
# [0 3 1 6 4 2 5]
# [0 1 2 3 4 5 6]
# [2 4 0 6 1 3 5]
# [0 2 3 4 1]
# [0 1 3 6 2 5 4]
#           Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0     0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1    -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2     0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3    -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4     0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...       ...      ...        ...      ...        ...      ...      ...
# 1880 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Ascore   Cscore  ...  Ecstasy  Heroin Ketamin LegalH LSD Meth  \
# 0    -0.58331 -0.91699 -0.00665  ...        0       0       0      0   0    0
# 1     1.43533  0.76096 -0.14277  ...        4       0       2      0   2    3
# 2    -0.84732 -1.62090 -1.01450  ...        0       0       0      0   0    0
# 3    -0.01928  0.59042  0.58489  ...        0       0       2      0   0    0
# 4    -0.45174 -0.30172  1.30612  ...        1       0       0      1   0    0
# ...       ...      ...      ...  ...      ...     ...     ...    ...  ..  ...
# 1880  1.88511  0.76096 -1.13788  ...        0       0       0      3   3    0
# 1881  0.58331  0.76096 -1.51840  ...        2       0       0      3   5    4
# 1882 -1.27553 -1.77200 -1.38502  ...        4       0       2      0   2    0
# 1883  0.29338 -1.62090 -2.57309  ...        3       0       0      3   3    0
# 1884  1.65653  1.11406  0.41594  ...        3       0       0      3   3    0
#
#      Mushrooms Nicotine Semer VSA
# 0            0        2     0   0
# 1            0        4     0   0
# 2            1        0     0   0
# 3            0        2     0   0
# 4            2        2     0   0
# ...        ...      ...   ...  ..
# 1880         0        0     0   5
# 1881         4        5     0   0
# 1882         2        6     0   0
# 1883         3        4     0   0
# 1884         3        6     0   2
#
# [1885 rows x 31 columns]

# %%
# #skaliramo podatke
# def skaliraj_podatke(X):
#     return (X - min(X))/(max(X) - min(X))

# %%
# for a in atributi:
#     podaci_skalirano[a] = skaliraj_podatke(podaci_skalirano[a])
    
# #provera uspesnosti skaliranja
# for a in atributi:
#     print(len(podaci_skalirano[a].unique()) == len(podaci[a].unique()), end = ", ")
    
# #nismo izgubili podatke

# %% [markdown]
# # pripremam skupove za klasifikaciju

# %%
podaci_bez_klasa = podaci_skalirano.copy()
for x in klase:
    podaci_bez_klasa = podaci_bez_klasa.drop(x, axis = 1)
podaci_bez_klasa.head()
# Out:
#        Age   Gender  Education  Country  Ethnicity   Nscore   Escore   Oscore  \
# 0  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545 -0.58331
# 1 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886  1.43533
# 2  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523 -0.84732
# 3 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615 -0.01928
# 4  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340 -0.45174
#
#     Ascore   Cscore  Impulsiveness       SS
# 0 -0.91699 -0.00665       -0.21712 -1.18084
# 1  0.76096 -0.14277       -0.71126 -0.21575
# 2 -1.62090 -1.01450       -1.37983  0.40148
# 3  0.59042  0.58489       -1.37983 -1.18084
# 4 -0.30172  1.30612       -0.21712 -0.21575

# %%
klasa = podaci['Alchocol']

# %%
podaci
# Out:
#           Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0     0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1    -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2     0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3    -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4     0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...       ...      ...        ...      ...        ...      ...      ...
# 1880 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Ascore   Cscore  ...  Ecstasy  Heroin Ketamin LegalH  LSD  \
# 0    -0.58331 -0.91699 -0.00665  ...      CL0     CL0     CL0    CL0  CL0
# 1     1.43533  0.76096 -0.14277  ...      CL4     CL0     CL2    CL0  CL2
# 2    -0.84732 -1.62090 -1.01450  ...      CL0     CL0     CL0    CL0  CL0
# 3    -0.01928  0.59042  0.58489  ...      CL0     CL0     CL2    CL0  CL0
# 4    -0.45174 -0.30172  1.30612  ...      CL1     CL0     CL0    CL1  CL0
# ...       ...      ...      ...  ...      ...     ...     ...    ...  ...
# 1880  1.88511  0.76096 -1.13788  ...      CL0     CL0     CL0    CL3  CL3
# 1881  0.58331  0.76096 -1.51840  ...      CL2     CL0     CL0    CL3  CL5
# 1882 -1.27553 -1.77200 -1.38502  ...      CL4     CL0     CL2    CL0  CL2
# 1883  0.29338 -1.62090 -2.57309  ...      CL3     CL0     CL0    CL3  CL3
# 1884  1.65653  1.11406  0.41594  ...      CL3     CL0     CL0    CL3  CL3
#
#      Meth Mushrooms Nicotine Semer  VSA
# 0     CL0       CL0      CL2   CL0  CL0
# 1     CL3       CL0      CL4   CL0  CL0
# 2     CL0       CL1      CL0   CL0  CL0
# 3     CL0       CL0      CL2   CL0  CL0
# 4     CL0       CL2      CL2   CL0  CL0
# ...   ...       ...      ...   ...  ...
# 1880  CL0       CL0      CL0   CL0  CL5
# 1881  CL4       CL4      CL5   CL0  CL0
# 1882  CL0       CL2      CL6   CL0  CL0
# 1883  CL0       CL3      CL4   CL0  CL0
# 1884  CL0       CL3      CL6   CL0  CL2
#
# [1885 rows x 31 columns]

# %%
# klasifikacija

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(podaci_bez_klasa, klasa, test_size= 0.30, stratify= klasa, random_state= 42)

# %%
Bajes = CategoricalNB()
Bajes.fit(X_train, y_train)
pred_trening = Bajes.predict(X_train)
pred_test = Bajes.predict(X_test)

# %%
accuracy_score(pred_trening, y_train)
# Out:
# 0.4086429112964367

# %%
accuracy_score(pred_test, y_test)
#confusion_matrix(y_test, pred)
# Out:
# 0.4010600706713781

# %%
ocene = {}

n = len(klase)
for i in range(n):
    X_train, X_test, y_train, y_test = train_test_split(podaci_bez_klasa, podaci[klase[i]], test_size= 0.30, stratify= klasa, random_state= 42)
    Bajes.fit(X_train, y_train)
    pred_trening = Bajes.predict(X_train)
    pred_test = Bajes.predict(X_test)
    
    ocene.update({klase[i]: round(accuracy_score(pred_test, y_test), 2)})
    
#     print(klase[i])
#     print(f'Trening: {round(accuracy_score(pred_trening, y_train), 2)}')
#     print(f'Test: {round(accuracy_score(pred_test, y_test), 2)}')
#     print()
# ocene

# %%
#deluje da naivni Bajes radi bolje od stabala odlucivanja, proveravam dalje to "tvrdjenje"

# %%
podaci_skalirano = podaci.copy()

n = len(podaci_skalirano['Heroin'])
    
for x in klase:
    for i in range(n):
        podaci_skalirano[x][i] = int(podaci_skalirano[x][i].strip('CL'))
    #print(podaci_skalirano[x].unique())
        

podaci_skalirano
# Out:
# /tmp/ipykernel_7320/2160653281.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   podaci_skalirano[x][i] = int(podaci_skalirano[x][i].strip('CL'))
#           Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0     0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1    -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2     0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3    -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4     0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...       ...      ...        ...      ...        ...      ...      ...
# 1880 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Ascore   Cscore  ...  Ecstasy  Heroin Ketamin LegalH LSD Meth  \
# 0    -0.58331 -0.91699 -0.00665  ...        0       0       0      0   0    0
# 1     1.43533  0.76096 -0.14277  ...        4       0       2      0   2    3
# 2    -0.84732 -1.62090 -1.01450  ...        0       0       0      0   0    0
# 3    -0.01928  0.59042  0.58489  ...        0       0       2      0   0    0
# 4    -0.45174 -0.30172  1.30612  ...        1       0       0      1   0    0
# ...       ...      ...      ...  ...      ...     ...     ...    ...  ..  ...
# 1880  1.88511  0.76096 -1.13788  ...        0       0       0      3   3    0
# 1881  0.58331  0.76096 -1.51840  ...        2       0       0      3   5    4
# 1882 -1.27553 -1.77200 -1.38502  ...        4       0       2      0   2    0
# 1883  0.29338 -1.62090 -2.57309  ...        3       0       0      3   3    0
# 1884  1.65653  1.11406  0.41594  ...        3       0       0      3   3    0
#
#      Mushrooms Nicotine Semer VSA
# 0            0        2     0   0
# 1            0        4     0   0
# 2            1        0     0   0
# 3            0        2     0   0
# 4            2        2     0   0
# ...        ...      ...   ...  ..
# 1880         0        0     0   5
# 1881         4        5     0   0
# 1882         2        6     0   0
# 1883         3        4     0   0
# 1884         3        6     0   2
#
# [1885 rows x 31 columns]

# %%
for x in klase:
    podaci_skalirano[x] = podaci_skalirano[x].astype('float64')
    
#podaci_skalirano.dtypes

# %%
for a in atributi:
    podaci_skalirano[a] = skaliraj_podatke(podaci_skalirano[a])
for a in klase:
    podaci_skalirano[a] = skaliraj_podatke(podaci_skalirano[a])
#podaci_skalirano.describe()

# %%
#pravi skupove podataka pojedinacno bez svake klase
podaci_bez_klase = []
for x in klase:
    podaci_bez_klase.append(podaci_skalirano.drop(x, axis = 1))
    
#klasni_podaci, isto to
klasni_podaci = []
n = len(klase)
for i in range(n):
    klasni_podaci.append(podaci[klase[i]])
    
len(podaci_bez_klase) == len(klasni_podaci)
# Out:
# True

# %%
n = len(podaci_bez_klase)
for i in range(n):
    
    X_train, X_test, y_train, y_test = train_test_split(podaci_bez_klase[i], podaci[klase[i]], test_size= 0.30, random_state= 42)
    Bajes.fit(X_train, y_train)
    
    pred_trening = Bajes.predict(X_train)    
    print(i)
#     pred_test = Bajes.predict(X_test)
    
    print(klase[i])
    print(f'Trening: {round(accuracy_score(pred_trening, y_train), 2)}')
#     print(f'Test: {round(accuracy_score(pred_test, y_test), 2)}')
    print()
# Out:
# 0
# Alchocol
# Trening: 0.41
#
# 1
# Amphet
# Trening: 0.53
#
# 2
# Amyl
# Trening: 0.69
#
# 3
# Benzos
# Trening: 0.53
#
# 4
# Caff
# Trening: 0.73
#
# 5
# Canabis
# Trening: 0.4
#
# 6
# Choc
# Trening: 0.44
#
# 7
# Coke
# Trening: 0.57
#
# 8
# Crack
# Trening: 0.84
#
# 9
# Ecstasy
# Trening: 0.55
#
# 10
# Heroin
# Trening: 0.84
#
# 11
# Ketamin
# Trening: 0.77
#
# 12
# LegalH
# Trening: 0.61
#
# 13
# LSD
# Trening: 0.59
#
# 14
# Meth
# Trening: 0.76
#
# 15
# Mushrooms
# Trening: 0.56
#
# 16
# Nicotine
# Trening: 0.4
#
# 17
# Semer
# Trening: 0.99
#
# 18
# VSA
# Trening: 0.75

# %%
# probacu sa balansiranjem klasa
# podaci_skalirano

# %%
X_train, X_test, y_train, y_test = train_test_split(podaci_bez_klase[0], podaci[klase[0]], test_size= 0.30, stratify= klasa, random_state= 42)

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42, sampling_strategy='minority')

# %%
X_balans, y_balans = ros.fit_resample(X_train, y_train)

Bajes = CategoricalNB()
Bajes.fit(X_balans, y_balans)
pred_trening = Bajes.predict(X_balans)
pred_test = Bajes.predict(X_test)

# print(accuracy_score(pred_trening, y_balans))
# print(accuracy_score(pred_test, y_test))

# %%
ocene_balans = {}

n = len(klase)
for i in range(n):
    X_train, X_test, y_train, y_test = train_test_split(podaci_bez_klasa, podaci[klase[i]], test_size= 0.30, stratify= klasa, random_state= 42)
    
    X_balans, y_balans = ros.fit_resample(X_train, y_train)
    Bajes.fit(X_balans, y_balans)
    
    pred_trening = Bajes.predict(X_balans)
    pred_test = Bajes.predict(X_test)
    
    ocene_balans.update({klase[i]: round(accuracy_score(pred_test, y_test), 2)})
    
#     print(klase[i])
#     print(f'Trening: {round(accuracy_score(pred_trening, y_train), 2)}')
#     print(f'Test: {round(accuracy_score(pred_test, y_test), 2)}')
#     print()
# ocene

# %%
for x in ocene_balans:
    print(round(ocene_balans[x] - ocene[x], 3), end = ' ') # ocaj
# Out:
# -0.09 -0.13 -0.1 -0.14 -0.38 -0.03 -0.09 -0.12 -0.19 -0.13 -0.19 -0.32 -0.24 -0.05 -0.23 -0.28 -0.02 -0.03 -0.25

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler()

# %%
ocene_balans = {}

n = len(klase)
for i in range(n):
    X_train, X_test, y_train, y_test = train_test_split(podaci_bez_klasa, podaci[klase[i]], test_size= 0.30, stratify= klasa, random_state= 42)
    
    X_balans, y_balans = rus.fit_resample(X_train, y_train)
    Bajes.fit(X_balans, y_balans)
    
    pred_trening = Bajes.predict(X_balans)
    pred_test = Bajes.predict(X_test)
    
    ocene_balans.update({klase[i]: round(accuracy_score(pred_test, y_test), 2)})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 11
#       8 Bajes.fit(X_balans, y_balans)
#      10 pred_trening = Bajes.predict(X_balans)
# ---> 11 pred_test = Bajes.predict(X_test)
#      13 ocene_balans.update({klase[i]: round(accuracy_score(pred_test, y_test), 2)})
#
# File ~/.local/lib/python3.10/site-packages/sklearn/naive_bayes.py:106, in _BaseNB.predict(self, X)
#     104 check_is_fitted(self)
#     105 X = self._check_X(X)
# --> 106 jll = self._joint_log_likelihood(X)
#     107 return self.classes_[np.argmax(jll, axis=1)]
#
# File ~/.local/lib/python3.10/site-packages/sklearn/naive_bayes.py:1530, in CategoricalNB._joint_log_likelihood(self, X)
#    1528 for i in range(self.n_features_in_):
#    1529     indices = X[:, i]
# -> 1530     jll += self.feature_log_prob_[i][:, indices].T
#    1531 total_ll = jll + self.class_log_prior_
#    1532 return total_ll
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
